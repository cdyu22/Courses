# %%
class Grades(object):
    
    def __init__(self,name):
        self.__name = name
        self.__score = []
        
    def get_name(self):
        return self.name
    
    def add_score(self, score):
        self.__score += [score]
    
    def get_scores(self):
        pass
    
    def get_max_score(self):
        pass

# %%
my_list = ['turtle',90,'dna',8.76]
my_list = my_list + [12]
my_list
# Out:
# ['turtle', 90, 'dna', 8.76, 12]
