# %%
class q_clas(c-clas):     
    def move(self):         
        print ('Slow and steady wins the race!') 
class w_clas():     
    def hide(self):         
        print('Burying my head in the sand.') 
class c_clas(t-clas):     
    def hide(self):         
        print('Going inside my shell.')          
class a_clas(c-clas):     
    def move(self):         
        print('Time to make the donuts!') 
class t_clas(w-clas):     
    def move(self):         
        print('Follow the moon!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5e110086fc70> in <module>
# ----> 1 class q_clas(c-clas):
#       2     def move(self):
#       3         print ('Slow and steady wins the race!')
#       4 class w_clas():
#       5     def hide(self):
#
# NameError: name 'c' is not defined

# %%
class w_clas():     
    def hide(self):         
        print('Burying my head in the sand.') 
class t_clas(w_clas):     
    def move(self):         
        print('Follow the moon!')
class c_clas(t_clas):     
    def hide(self):         
        print('Going inside my shell.')          
class a_clas(c_clas):     
    def move(self):         
        print('Time to make the donuts!') 
class q_clas(c_clas):     
    def move(self):         
        print ('Slow and steady wins the race!')

# %%
one = q_clas() 
two = c_clas() 
three = w_clas() 
four = a_clas() 
five = t_clas() 
one.move() 
two.move() 
three.move()
# Out:
# Slow and steady wins the race!
# Follow the moon!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-16e39c88d6f2> in <module>
#       6 one.move()
#       7 two.move()
# ----> 8 three.move()
#
# AttributeError: 'w_clas' object has no attribute 'move'

# %%
one = q_clas() 
two = c_clas() 
three = w_clas() 
four = a_clas() 
five = t_clas() 
 
four.move() 
five.move() 
 
one.hide() 
two.hide() 
three.hide() 
four.hide() 
five.hide()
# Out:
# Time to make the donuts!
# Follow the moon!
# Going inside my shell.
# Going inside my shell.
# Burying my head in the sand.
# Going inside my shell.
# Burying my head in the sand.

# %%
#2a
import datetime
Frank = datetime.date(1998,10,2)
print(Frank.isoweekday())
# Out:
# 5

# %%
#2b
import datetime
date = datetime.datetime(1942,3,19,10,15,0)
date = date.replace(day=1)
print(date)
# Out:
# 1942-03-04 10:15:00

# %%
#3
class counter(object):
    def __init__(self, limit, initial, min_digits):
        self.limit = limit
        self.count = initial
        if (self.count>self.limit) or (self.count < -1):
            self.count = self.limit-1
            print("The input for initial value is invalid, and is set to be limit-1")
        self.min_digits = min_digits

    def get_value(self):
        return self.count

    def __str__(self):
        value = str(self.min_digits)*"0"
        int(value)
        value+=self.count
        return value

# %%
Frank = counter(6,7,2)
print(length)
# Out:
# The input for initial value is invalid, and is set to be limit-1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-96a68ea0c28c> in <module>
#       1 Frank = counter(6,7,2)
# ----> 2 print(length)
#
# NameError: name 'length' is not defined
