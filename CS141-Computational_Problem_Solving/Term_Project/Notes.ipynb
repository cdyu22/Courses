# %%
#The player will place bubbles by clicking. After each valid click the computer will choose a random square to place.
#Blocker can be placed ANYWHERE.
#Bubbles disappear when 4 of them.
#Disappeared bubbles are points. Points should be kept updated.
#After one bubble placement more than one can disappear. If that happens, we have a multiplier effect. Need to explain how
#Multiplier works in right-up. Increases linearly, so one line of bubbles gives points, but if two lines disappear multiplier 
#is two, so on and so forth.
#Three lines is x4 points.
#If the player forms 0 or 1 line in one bubble placeme, multiplier should be reset to 1.

# %%
#Need to display multiplier as well.
#multiplier will display as 2 if there was a multiplier of two.
#So if you erase 2 lines then two lines, what's the multiplier?
#Want to make th game more attractive, make it more fun.

# %%
#Easter version?
#Made circles rabbits and blockers bombs

# %%
#For dazzle, there's basic functionalality, but we need additional features, can't change basic functionality.
#Example: In previous semester students tried to add more difficulty levels.
#Music and buttons are easy, but there are additional things we can add like difficulty levels, or human v human or
#AI vs AI

# %%
#Deadline is May 3, 10:00, but should put it in by 2. Teacher suggests we should save constantly. No excuses, no extensions.
