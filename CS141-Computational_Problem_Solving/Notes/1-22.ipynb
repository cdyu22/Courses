# %%
12+14
# Out:
# 26

# %%
8*9
# Out:
# 72

# %%
1-5*13
# Out:
# -64

# %%
(1-5)*13
# Out:
# -52

# %%
2**4
# Out:
# 16

# %%
2.0**4
# Out:
# 16.0

# %%
type(100)
# Out:
# int

# %%
type(2.5)
# Out:
# float

# %%
2**100
# Out:
# 1267650600228229401496703205376

# %%
2.0**100
# Out:
# 1.2676506002282294e+30

# %%
1.0+2
# Out:
# 3.0

# %%
int(3.0)
# Out:
# 3

# %%
float(3)
# Out:
# 3.0

# %%
int(3)
# Out:
# 3

# %%
int(1.2+2)
# Out:
# 3

# %%
1.2+2
# Out:
# 3.2

# %%
float(12+23)
# Out:
# 35.0

# %%
14/3
# Out:
# 4.666666666666667

# %%
12/2
# Out:
# 6.0

# %%
14//3
# Out:
# 4

# %%
14%3
# Out:
# 2

# %%
3.14*10**2
# Out:
# 314.0

# %%
r = 10
area = 3.14*r**2
print(area)
# Out:
# 314.0

# %%
print(r)
# Out:
# 10

# %%
area
# Out:
# 314.0

# %%
import math
r=10
area=math.pi*r**2
print(area)
# Out:
# 314.1592653589793

# %%
a=3

# %%
a +=2

# %%
a=6

# %%
a
# Out:
# 6

# %%
b='6'

# %%
b
# Out:
# '6'

# %%
type(b)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
c=10%5

# %%
print(c)
# Out:
# 0

# %%
b=False

# %%
b
# Out:
# False

# %%
a='10'

# %%
b=a*3
print(b)
# Out:
# 101010

# %%
b=b+a

# %%
print(b)
# Out:
# 10101010

# %%
a = '5' + '3'

# %%
a
# Out:
# '53'

# %%
1x=4
# Out:
#   File "<ipython-input-17-f6632e082fa5>", line 1
#     1x=4
#      ^
# SyntaxError: invalid syntax

# %%
a=4
b=a

# %%
b
# Out:
# 4

# %%
a=10
b=a

# %%
a
# Out:
# 10

# %%
b
# Out:
# 10

# %%
continue=5
# Out:
#   File "<ipython-input-23-bb02920296f9>", line 1
#     continue=5
#             ^
# SyntaxError: invalid syntax

# %%
x1 = float(input("Enter the x coordinate of point 1: "))
y1 = float(input("Enter the y coordinate of point 1: "))
x2 = float(input("Enter the x coordinate of point 2: "))
y2 = float(input("Enter the y coordinate of point 2: "))
import math
distance = math.sqrt((x1-x2)**2 + (y1-y2)**2)
print("The distance between point 1 and point 2 is: ",distance,".")
# Out:
# Enter the x coordinate of point 1: 1
# Enter the y coordinate of point 1: 0
# Enter the x coordinate of point 2: 3
# Enter the y coordinate of point 2: 2
# The distance between point 1 and point 2 is:  2.8284271247461903 .

# %%
c='None'
c=(c==None)
print(c)
# Out:
# False
