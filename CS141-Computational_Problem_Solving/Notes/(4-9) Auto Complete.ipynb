# %%
class Auto_Complete(object):

    def __init__(self):
        self.__auto_struct = {}# fill in code to set up empty dictionary

    def add_entry(self, user_input, suggested_words):
        self.__auto_struct[user_input] = suggested_words
        # fill in the method to add a new entry

    def add_to_entry(self, user_input, word):
        self.__auto_struct[user_input] += word
        #or self.__auto_struct[user_input].append(word)
        # fill in the method to add a new suggested word for a given input

    def get_entry(self, user_input):
        try:
            return self.__auto_struct[user_input]
        except KeyError:
            return 'No suggested word for it.'
        
        # fill in the method to retrieve the suggested words based on a user_input string, return the suggested words

# %%
corrector = Auto_Complete()

# %%
corrector.add_entry('defetly',['definitely','defeat'])
print(corrector.get_entry('defetly'))
print(corrector.get_entry('trtle'))
corrector.add_to_entry('defetly',['defiantly'])
print(corrector.get_entry('defetly'))
corrector.add_entry('bagle',['bagel','beagle','baguette'])
corrector.add_entry('piza',['pizza'])
corrector.add_entry('tost',['toast','rose'])
corrector.add_to_entry('piza',['pizzaz'])
print(corrector.get_entry('piza'))
# Out:
# ['definitely', 'defeat']
# No suggested word for it.
# ['definitely', 'defeat', 'defiantly']
# ['pizza', 'pizzaz']

# %%
corrector = {}

# %%
corrector['bagle'] = ['bagle','beagle','baguette']
corrector['piza'] = ['pizza']
corrector['tost'] =['toast','rose']
corrector['piza'] += ['pizzaz']

# %%
print(corrector['bagle'])
# Out:
# ['bagle', 'beagle', 'baguette']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-0190a01da5d4> in <module>
#       1 print(corrector['bagle'])
# ----> 2 print(corrector['trtle'])
#
# KeyError: 'trtle'

# %%
print(corrector)
# Out:
# {'bagle': ['bagle', 'beagle', 'baguette'], 'piza': ['pizza', 'pizzaz'], 'tost': ['toast', 'rose']}

# %%
try:#will try this part
    print(corrector['trtle'])
except KeyError:#Will only fall into the excepted block if it sees the errors name is KeyError
    pass
print('You spelled that so badly that I cannot suggest anything.')
# Out:
# You spelled that so badly that I cannot suggest anything.

# %%
print(corrector['trtle'])#can't continue with the rest of the program. However, if you use the try except block, it will
#continue on with the project.
print('Still in the program')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-2c08e4dfb81b> in <module>
# ----> 1 print(corrector['trtle'])
#       2 print('Still in the program')
#
# KeyError: 'trtle'

# %%
print(corrector.keys())
print(corrector.items())
# Out:
# dict_keys(['bagle', 'piza', 'tost'])
# dict_items([('bagle', ['bagle', 'beagle', 'baguette']), ('piza', ['pizza', 'pizzaz']), ('tost', ['toast', 'rose'])])

# %%
for key in corrector:
    print(key)
    print(corrector[key])
# Out:
# bagle
# ['bagle', 'beagle', 'baguette']
# piza
# ['pizza', 'pizzaz']
# tost
# ['toast', 'rose']
