# %%
#Instead of defining a new class, inherit the attributes, including variables and methods from another class. One class can inherit
#all attributes including instance variables and methods from another class. Syntax is:
class class_1(class_2):
    #Class_1 is usually called child class or subclass. Call Class_2 the parent class or super class. 
    #Can inherit all of th instance variables and methods. The syntax is the same as above. class class_1(class_2): if you leave
    #it empty or use object it'll have all of the default things (???). If you inherit from class_2 we usually call the class 
    # that is inheriting the child or sub class. The class you're inheriting it from is the parent class or the s
