# %%
class Grades(object):
    
    def __init__(self,name):
        self.__name = name
        self.__score = []
        
    def get_name(self):
        return self.name
    
    def add_score(self, score):
        #self.__score += [score]
        self.__scores.append(score)
    
    def get_scores(self):
        return self.__scores
    
    def get_max_score(self):
        pass

# %%
student = Grades('Alice')
print(student.get_scores())
# Out:
# None

# %%
student.add_score(80)
student.add_score(100)

# %%
(student.get_scores())

# %%
student.get_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-afcc6e4c8279> in <module>
# ----> 1 student.get_name()
#
# <ipython-input-1-5d3dcb097c16> in get_name(self)
#       6
#       7     def get_name(self):
# ----> 8         return self.name
#       9
#      10     def add_score(self, score):
#
# AttributeError: 'Grades' object has no attribute 'name'
