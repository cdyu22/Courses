# %%
def a(num):
    i=0
    result = 0
    while(num>i):
        result = 1/num
        num -= 1
print(a(100))
# Out:
# None

# %%
def a(num):
    i=0
    result = 0
    while(num>i):
        result = 1/num
        num -= 1
    return result
    
print(a(100))
# Out:
# 1.0

# %%
def a(num):
    i=2
    sum=1/i
    while(i<100):
        sum=sum+(1/i)
        i=i+1

print(a(100))
# Out:
# None

# %%
x = float(input("What's x? "))
if(x % 2 == 0 or x //2 == 0 and x/2 <5):
    print("Time present and time past")
elif(x**0.5 > 5):
    print("Are both perhaps present in time future")
else:
    print("And time future contained in time past")
if(x+2>10):
    x*=2
    print("Humpty Dumpty sat on a wall")
elif(x//4 == 1):
    print("Unfortunately, there are eels in my spacecraft")
if(x==7):
    print("I'm actually not joking")
else:
    print("But no snakes on my plane")
# Out:
# What's x? 2
# Time present and time past
# But no snakes on my plane

# %%
def var(var):
    if var == 50:
        print("condition 1")
    elif var==50:
        print("Condition 2")

# %%
var(50)
# Out:
# condition 1

# %%
value = int(input("Enter an integer: "))
if value < 0:
    if value > -1:
        print('A')
    elif value > 0:
        print('B')
    else:
        print('C')
else:
    if value > 100:
        print('D')
    if value > 150:
        print('E')
        if value > 200:
            print('F')
        else:
            print('G')
    elif value < 125:
        print('H')
    print('I')
# Out:
# Enter an integer: 101
# D
# H
# I

# %%
i=2
sum=1/i
while(i<100):
    sum=sum+(1/i)
    i=i+1
