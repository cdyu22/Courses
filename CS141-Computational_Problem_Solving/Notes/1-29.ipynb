# %%
print(type('hello world'))
# Out:
# <class 'str'>

# %%
a = int(6.5)
#call function first, then the value is assigned to A
print(a)
# Out:
# 6

# %%
b=pow(2,4)
print(b)
# Out:
# 16

# %%
b=pow(3,2,3)
#z loks for remainder after 3
print(b)
# Out:
# 0

# %%
import math
c=math.factorial(6)
print(c)
# Out:
# 720

# %%
import random
d=random.randint(0,4)
print(d)
# Out:
# 4

# %%
from random import randint,randrange
e= randint (0,3)
f= randrange(0,4)
print(e)
print(f)
# Out:
# 3
# 1

# %%
#temp is the argument, the input we need. Defines C_to_F as a new function.
def C_to_F(temp):
    F=temp*(9/5)+32
    print(F)

# %%
T = C_to_F(37)
print(T)
# Out:
# 98.60000000000001
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-d8b914e8511d> in <module>
#       1 T = C_to_F(37)
#       2 print(T)
# ----> 3 print(xyz)
#
# NameError: name 'xyz' is not defined
