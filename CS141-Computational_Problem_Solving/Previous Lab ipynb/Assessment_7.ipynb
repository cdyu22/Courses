# %%
my_test = 'MCHammer'
for i in range(0,len(my_test)+1,3):
   print(my_test[:i:-1].lower())
# Out:
# remmahc
# remm
# r

# %%
a = ['turtle','potato', 'bagel']
a[1][0] = 'P'
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c1d42c35ec5a> in <module>
#       1 a = ['turtle','potato', 'bagel']
# ----> 2 a[1][0] = 'P'
#       3 print(a)
#
# TypeError: 'str' object does not support item assignment
