# %% [markdown]
# Explain why the values of a_var and b_var are different as demonstrated by the print statement:

# %%
a_var = 3
b_var = a_var
a_var = 4
print(a_var, b_var)
# Out:
# 4 3

# %% [markdown]
# What are the types of a_var and b_var after this code executes?

# %%
a_var = 3
b_var = a_var + 1
a_var += 2.25 #Note the syntax here
b_var /=2
print(a_var, b_var)
# Out:
# 5.25 2.0

# %% [markdown]
# Which objects are lost in space after this program runs?

# %%
a = 7
b = 'turtle'
c = a-2
a = c**2 #Exponentiation
d = a
c = d
#7 and 5 are lost, as no variable is assigned to them

# %% [markdown]
# What is the problem with the code below?

# %%
i = j+3
print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-19c78f23a27d> in <module>
# ----> 1 i = j+3
#       2 print(i)
#
# NameError: name 'j' is not defined

# %%
d
# Out:
# 25
