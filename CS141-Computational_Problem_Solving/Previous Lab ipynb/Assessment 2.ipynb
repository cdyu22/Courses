# %%
#1
temp  = float(input('Enter temperature in Fahrenheit: '))
Cel = (temp - 32) * 5/9
Kel = Cel + 273.15
print('The temperature in Kelvin is', Kel)
# Out:
# Enter temperature in Fahrenheit: 0
# The temperature in Kelvin is 255.3722222222222

# %%
#3
def convert(temp):
   print ((temp-32)*5/9+273.15)

# %%
print(convert(32))
# Out:
# 273.15
# None

# %%
#8
def convert(degrees):
    degrees += 273.15
    return degrees

degrees = 10
print(convert(degrees))
# Out:
# 283.15

# %%
#9
def convert():
    degrees += 273.15

degrees = 10
print(convert())
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-bb2d5f0a3f94> in <module>
#       4
#       5 degrees = 10
# ----> 6 print(convert())
#
# <ipython-input-8-bb2d5f0a3f94> in convert()
#       1 #9
#       2 def convert():
# ----> 3     degrees += 273.15
#       4
#       5 degrees = 10
#
# UnboundLocalError: local variable 'degrees' referenced before assignment

# %%
#10
def convert():
    print('After conversion, there are', degrees + 273.15, 'degrees')

degrees = 10
print(convert())
# Out:
# After conversion, there are 283.15 degrees
# None
