# %%
#1
def func_one(a):
    result = 0
    for i in range(len(str(a))):
        result += a%10
        a = a//10
    return result

# %%
func_one(-10)
# Out:
# 18

# %%
def func_one1(a):
    result = 0
    while (a>0):
        result += a % 10
        a = a // 10
    return result

# %%
func_one1(-4)
# Out:
# 0

# %%
#2
def play_nims(pile, max_marbles):
    print("The number of marbles in the pile to start is: " + str(pile))
    print("The maximum number of marbles the players can take on one turn is: " + str(max_marbles))
    whose_turn = 0
    while (pile > 0):
        print("The player " + str(whose_turn) + "'s turn:")
        marbles = int(input("How many marbles do you want to take?"))
        while (marbles <= 0) or (marbles > max_marbles) or (marbles > pile):
            marbles = int(input("Invalid input! How many marbles do you want to take?"))
        return
        print("The pile has " + str(pile) + " marbles in it.")
        if (pile == 0):
            print("The player " + str(whose_turn) + ' wins!')
            pile -= max_marbles
        whose_turn = (whose_turn + 1) % 2

# %%
#Missing Line 1: while (pile > 0):
#Missing Line 2: while (marbles <= 0) or (marbles > max_marbles) or (marbles > pile):
#Missing Line 3: pile -= marbles
#Missing Line 4: if (pile == 0):
#Missing Line 5: pile -= max_marbles
#Missing Line 6: whose_turn = (whose_turn + 1) % 2

# %%
#str(ex) in print doesn't change the actual class

# %%
play_nims(20,5)
# Out:
# The number of marbles in the pile to start is: 20
# The maximum number of marbles the players can take on one turn is: 5
# The player 0's turn:
# How many marbles do you want to take?6
# Invalid input! How many marbles do you want to take?-1
# Invalid input! How many marbles do you want to take?0
# Invalid input! How many marbles do you want to take?4

# %%
#3

# %%
s = 'I had a cat named amanda when I was little'
count = 0
for c in s:
    if (c == "a"):
        count += 1
print(count)
# Out:
# 8

# %%
s = 'I had aa cat named amanda when I was little'
count = str.count(s,"a")
print(count)
# Out:
# 9

# %%
#4

# %%
s = 'p@55w-rd'
result = ''
for c in s:
    if(c not in 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'):#if not letter or number 
        result += '*'
    else:
        result += c
print(result)
# Out:
# p*55w*rd

# %%
#a
s = 'p@55w-rd'
result = ''
for c in s:
    if(str.isalnum(c)==False):
        result += '*'
    else:
        result += c
print(result)
# Out:
# p*5aw31**5w*rd

# %%
#b
s = 'p@55w-rd'
result = ''
for c in s:
    if(c not in 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'):
        s = str.replace(s,c,"*")
print(s)
# Out:
# p*55w*rd
