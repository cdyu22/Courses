# %%
class q_class(c_class):     
    def move(self):         
        print ('Slow and steady wins the race!') 
class w_class(object):     
    def hide(self):         
        print('Burying my head in the sand.') 
class c_class(t_class):     
    def hide(self):         
        print('Going inside my shell.')          
class a_class(c_class):     
    def move(self):         
        print('Time to make the donuts!') 
class t_class(w_class):     
    def move(self):         
        print('Follow the moon!')

# %%
class w_class(object):     
    def hide(self):         
        print('Burying my head in the sand.') 
class t_class(w_class):     
    def move(self):         
        print('Follow the moon!')
class c_class(t_class):     
    def hide(self):         
        print('Going inside my shell.')          
class a_class(c_class):     
    def move(self):         
        print('Time to make the donuts!') 
class q_class(c_class):     
    def move(self):         
        print ('Slow and steady wins the race!')

# %%
one = q_class() 
two = c_class() 
three = w_class() 
four = a_class() 
five = t_class() 

one.move() 
two.move() 
three.move()
# Out:
# Slow and steady wins the race!
# Follow the moon!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-42b3721231be> in <module>
#       7 one.move()
#       8 two.move()
# ----> 9 three.move()
#
# AttributeError: 'w_class' object has no attribute 'move'

# %%
one = q_class() 
two = c_class() 
three = w_class() 
four = a_class() 
five = t_class() 
 
four.move() 
five.move() 
 
one.hide() 
two.hide() 
three.hide() 
four.hide() 
five.hide()
# Out:
# Time to make the donuts!
# Follow the moon!
# Going inside my shell.
# Going inside my shell.
# Burying my head in the sand.
# Going inside my shell.
# Burying my head in the sand.

# %%
#2a
import datetime
Frank = datetime.date(1998,10,2)
print(Frank.isoweekday())
# Out:
# 5

# %%
#2b
import datetime
date = datetime.datetime(1942,3,19,10,15,0)
date = date.replace(day=1)
print(date)
# Out:
# 1942-03-04 10:15:00

# %%
class counter(object):
    def __init__(self, limit, initial, min_digits):
        self.__limit = limit
        self.__count = initial
        if (self.__count>self.__limit) or (self.__count < 0):
            self.__count = self.__limit-1
            print("The input for initial value is invalid, and is set to be limit-1")
        self.__min_digits = min_digits

    def get_value(self):
        return self.__count

    def __str__(self):
        value = str(self.__count)
        value = len(value)
        value = self.__min_digits - value
        return (value*"0")+str(self.__count)

    def tick(self):
        self.__count = self.__count-1
        if self.__count < 0:
            self.__count = self.__limit - 1
            return True
        else:
            return False

# %%
my_counter = counter(10,9,3)
print(my_counter)
print(my_counter.get_value())
for i in range(5):
    print(my_counter.tick())
print(my_counter)
# Out:
# 009
# 9
# False
# False
# False
# False
# False
# 004

# %%
value = "Ten"
value = len(value)
type(value)
# Out:
# int

# %%
#DEFINITIVE
class w_class(object):     
    def hide(self):         
        print('Burying my head in the sand.') 
class t_class(w_class):     
    def move(self):         
        print('Follow the moon!')
class c_class(t_class):     
    def hide(self):         
        print('Going inside my shell.')          
class a_class(c_class):     
    def move(self):         
        print('Time to make the donuts!') 
class q_class(c_class):     
    def move(self):         
        print ('Slow and steady wins the race!')

# %%
#2a
import datetime
Frank = datetime.date(1998,10,2)
print(Frank.isoweekday())
# Out:
# 5

# %%
#2b
import datetime
the_date = datetime.datetime(1942,3,19,10,15,0)
the_date = the_date.replace(hour=22)
print(the_date)
# Out:
# 1942-03-19 22:15:00
